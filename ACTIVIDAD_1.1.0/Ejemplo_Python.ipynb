# %% [markdown]
# # Hello world

# %%
print ("Hello world")
# Out:
# Hello world

# %% [markdown]
#  1. numpy

# %%
# %pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.6 MB 9.3 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/12.6 MB 9.1 MB/s eta 0:00:02
#    ------------------ --------------------- 5.8/12.6 MB 10.3 MB/s eta 0:00:01
#    ------------------------- -------------- 8.1/12.6 MB 10.5 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 10.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
#  2. sympy

# %%
 # %pip install sympy
# Out:
# ...
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.3 MB 2.5 MB/s eta 0:00:03
#    ------ --------------------------------- 1.0/6.3 MB 2.5 MB/s eta 0:00:03
#    --------- ------------------------------ 1.6/6.3 MB 2.5 MB/s eta 0:00:02
#    ------------------ --------------------- 2.9/6.3 MB 3.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.3 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.3 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 5.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 2.7 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
# ...

# %% [markdown]
#  3. matplotlib

# %%
 # %pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 7.6 MB/s eta 0:00:01
#    ------------------ --------------------- 3.7/8.1 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 12.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 10.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------  2.6/2.7 MB 18.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 11.1 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
# ...

# %% [markdown]
#  4. pandas

# %%
 # %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.5 MB 6.8 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.5 MB 7.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.7/11.5 MB 8.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.1/11.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 11.0 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
# ...

# %% [markdown]
#  5. scipy

# %%
 # %pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#    - -------------------------------------- 1.3/41.0 MB 7.8 MB/s eta 0:00:06
#    -- ------------------------------------- 2.9/41.0 MB 7.7 MB/s eta 0:00:05
#    --- ------------------------------------ 3.9/41.0 MB 7.0 MB/s eta 0:00:06
#    ------- -------------------------------- 7.6/41.0 MB 9.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 10.7/41.0 MB 10.8 MB/s eta 0:00:03
#    ------------ --------------------------- 12.6/41.0 MB 10.6 MB/s eta 0:00:03
#    -------------- ------------------------- 14.7/41.0 MB 10.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 16.5/41.0 MB 10.2 MB/s eta 0:00:03
#    ------------------ --------------------- 18.6/41.0 MB 10.2 MB/s eta 0:00:03
#    ------------------- -------------------- 20.4/41.0 MB 10.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 22.5/41.0 MB 10.1 MB/s eta 0:00:02
# ...

# %% [markdown]
#  6. yfinance

# %%
 # %pip install yfinance
# Out:
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      ------ --------------------------------- 0.5/3.0 MB 956.3 kB/s eta 0:00:03
#      ---------- ----------------------------- 0.8/3.0 MB 1.0 MB/s eta 0:00:03
#      ------------- -------------------------- 1.0/3.0 MB 1.1 MB/s eta 0:00:02
#      ----------------- ---------------------- 1.3/3.0 MB 1.1 MB/s eta 0:00:02
#      -------------------- ------------------- 1.6/3.0 MB 1.2 MB/s eta 0:00:02
#      ------------------------ --------------- 1.8/3.0 MB 1.1 MB/s eta 0:00:02
#      ------------------------ --------------- 1.8/3.0 MB 1.1 MB/s eta 0:00:02
#      --------------------------- ------------ 2.1/3.0 MB 1.1 MB/s eta 0:00:01
# ...

# %% [markdown]
#  7. scikit-learn

# %%
 # %pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    --------- ------------------------------ 2.6/11.1 MB 12.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/11.1 MB 14.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.5/11.1 MB 16.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 14.2 MB/s eta 0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
# ...
